# %%
# !pip install ipython-sql
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 42 kB 285 kB/s
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      |████████████████████████████████| 1.6 MB 2.2 MB/s
# ...
#      |████████████████████████████████| 150 kB 47.0 MB/s
# ...
#   Created wheel for prettytable: filename=prettytable-0.7.2-py3-none-any.whl size=13699 sha256=011c85f912828d6f6be4bb03c21586e5ac9aa1e6b28d57de561a46706e40418d
#   Stored in directory: /DATA/radhasyam1/.cache/pip/wheels/b2/7f/f6/f180315b584f00445045ff1699b550fa895d09471337ce21c6
# Successfully built prettytable
# ...
#   Attempting uninstall: prettytable
#     Found existing installation: prettytable 2.2.1
#     Uninstalling prettytable-2.2.1:
#       Successfully uninstalled prettytable-2.2.1
# ...

# %%
import sqlalchemy

# %%
sqlalchemy.create_engine('postgres://keshav:keshav@localhost:5432/postgres')

# %%
# %load_ext sql

# %%
# %%sql
# SELECT TOP(5) * FROM avengers_csv
# Out:
#                                                  url  \
# 0      http://marvel.wikia.com/henry_pym_(earth-616)
# 1  http://marvel.wikia.com/janet_van_dyne_(earth-...
# 2  http://marvel.wikia.com/anthony_stark_(earth-616)
# 3  http://marvel.wikia.com/robert_bruce_banner_(e...
# 4   http://marvel.wikia.com/thor_odinson_(earth-616)
#
#                     name/alias  appearances current?  gender  \
# 0    henry jonathan "hank" pym         1269      yes    male
# 1               janet van dyne         1165      yes  female
# 2  anthony edward "tony" stark         3068      yes    male
# 3          robert bruce banner         2089      yes    male
# 4                 thor odinson         2402      yes    male
#
#   probationary introl full/reserve avengers intro  year  years since joining  \
# 0                 NaN                      sep-63  1963                   52
# 1                 NaN                      sep-63  1963                   52
# ...

# %%
# %%sql
# SELECT TOP(5)
# name/alias, appearances, gender
# FROM avengers_csv
# Out:
#                     name/alias  appearances  gender
# 0    henry jonathan "hank" pym         1269    male
# 1               janet van dyne         1165  female
# 2  anthony edward "tony" stark         3068    male
# 3          robert bruce banner         2089    male
# 4                 thor odinson         2402    male
